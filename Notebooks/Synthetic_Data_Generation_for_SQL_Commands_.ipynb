# %% [markdown]
# #**Synthetic Data Generation for SQL Commands**

# %% [markdown]
# This notebook demonstrates an automated approach to synthetic data generation for instruction-response datasets, where each instruction (or question) is paired with a corresponding SQL command as a response. The goal is to streamline the process of creating datasets that can be used for fine-tuning AI models capable of understanding and producing SQL commands from natural language instructions.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Why Do We Generate Data?**
#
# Data is all around us, it's the foundation for making decisions, powering AI models, and shaping the future of businesses, organizations, and society. But sometimes, real-world data isn’t easy to access. It could be difficult to collect, too expensive to obtain, or too sensitive to use.
#
# This is where synthetic data comes into play. It’s computer-generated data that mimics the structure and patterns of real-world data, offering a solution that lets us explore and analyze insights without the risks associated with using actual, sensitive information.
#
# Here’s why generating synthetic data is so important:
#
# - **Fine-Tuning AI Models:** The synthetic datasets we create are perfect for fine-tuning AI models, helping them understand various tasks like natural language processing and SQL command generation, without the need for large volumes of real-world data.
#
# - **Cost and Time Efficiency:** Generating synthetic data saves significant time and resources compared to manually collecting and curating real-world datasets. This method ensures high-quality results without the hassle.
#
# - **Broad AI Applications:** Synthetic data isn't just for training models; it’s also used for testing, data augmentation, and benchmarking. By providing a diverse set of examples, synthetic data helps AI models generalize better, ultimately leading to improved real-world performance.
#
# Synthetic data is a game-changer, offering a practical, efficient, and secure way to enhance AI systems and unlock new possibilities across industries.

# %% [markdown]
# ##**How It Works**
# Here’s the game plan:
#
#
# * **Subtopic Generation**: Prompt the model to generate SQL-related subtopics like Data Retrieval, Joins, Aggregations, etc.
#
# * **Instruction Generation**: For each subtopic, prompt the model to create natural language instructions or questions.
#
# * **SQL Response Generation**: Prompt the model to generate SQL commands corresponding to each instruction.
#
# * **Dataset Filtering**: Use a reward model to filter out low-quality instruction-SQL pairs, ensuring only relevant responses are retained.

# %% [markdown]
# #**Let's Get Started!**

# %% [markdown]
# ## **Step 1: Setting Up the Environment**
#
# We prepare the environment by installing necessary libraries and establishing a connection to Hugging Face's Inference API. This setup allows us to access the **Qwen2.5-72B-Instruct** model, which I chose for its ability to generate SQL commands directly without any additional text when prompted. By creating a dataset from its responses, we can fine-tune a model on its answering style, ensuring high-quality SQL command generation. (You can pick any other model for your used case)

# %%
# %%capture
# !pip install openai==1.55.3 httpx==0.27.2 --force-reinstall --quiet

# %%
import os
os.kill(os.getpid(), 9)

# %%
from huggingface_hub import InferenceClient

client = InferenceClient(api_key="")
MODEL = "Qwen/Qwen2.5-72B-Instruct"

# %% [markdown]
# ## **Step 2: Generating Subtopics**
#
# Here, we focus on generating a set of subtopics related to the broader topic of SQL commands. The goal is to create a list of distinct SQL categories that we can later use to generate natural language instructions and corresponding SQL queries. While I chose SQL commands as the focus for this project, you could easily adapt this approach to generate subtopics for any other area of interest.
#
# - **Prompt Template:** We define a prompt that asks the model to generate a list of subtopics related to SQL commands. The prompt specifies that the subtopics should be general categories (such as "Data Manipulation" or "Joins") and must not include numbers, descriptions, or any extraneous text.
#
# - **Generating Subtopics:** Using the Hugging Face InferenceClient, we pass the prompt to the **Qwen2.5-72B-Instruct** model, which generates a list of subtopics. In our example, we are asking for **10** subtopics related to SQL commands, but you can adjust this number.
#
# By generating these subtopics, we lay the foundation for the rest of the notebook.

# %%
n_subtopics = 10
TOPIC_GENERATION_PROMPT_TEMPLATE = """\
I want to create a synthetic dataset of natural language and SQL commands. Based on this context, give me {n_subtopics} general subtopics to cover
that are diffrent sql command categories.

The list must be without numbers, and without any description of the subtopics. The subtopics should be separated by a comma. There must be no other text than the list and no ().
"""

# %%
def generate_subtopics(client, n_subtopics):
    prompt = TOPIC_GENERATION_PROMPT_TEMPLATE.format(n_subtopics=n_subtopics)
    response = client.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "user",
             "content": prompt}
        ],
        temperature=0.2,
        top_p=0.7,
    )
    return response

# %%
responses = generate_subtopics(client, n_subtopics=n_subtopics)
print(responses.choices[0].message.content)
# Out:
# Data Retrieval, Data Manipulation, Data Definition, Data Control, Transaction Control, Query Optimization, Error Handling, Security Management, Index Management, View Management

# %% [markdown]
# ## **Step 3: Generating Instructions**
#
# Now that we have our subtopics, the next step is to generate natural language instructions related to each of those subtopics. These instructions are meant to be concise queries or requests that would correspond to SQL commands, serving as the basis for generating synthetic datasets.
#
# - **Prompt Template for Instruction Generation:** We define a template that asks the model to generate **n_instructions** related to a specific SQL subtopic. The instructions should be simple and clear, with some written as if they come from a beginner or someone with limited SQL knowledge. This helps ensure the instructions are realistic and can mimic real user interactions.
#
# - **Generating Instructions:** For each subtopic (like "Data Manipulation" or "Joins"), we pass the template to the **Qwen2.5-72B-Instruct** model. The model generates a list of instructions in natural language.
#
# - **Processing Multiple Subtopics:** We apply the instruction generation function to all the subtopics generated earlier. For each subtopic, we get a list of instructions that we then format into a single, unified list.
#
# This step ensures that we have a variety of instructions for each SQL subtopic.

# %%
n_instructions = 20
INSTRUCTION_PROMPT_TEMPLATE = """\
The objective is to create a dataset of user instructions in natural language that should be returned by SQL commands.
Given a topic in SQL, generate {n_instructions} possible concise instructions that could be given to an AI assistant about that topic.
Write some of these instructions as if given by someone with limited knowledge of SQL terminologies and knowledge,
like a beginner programmer. Your response should be in a list format.

The topic is: {sub_topic}
The list must be without numbers or any special character. The questions/instructions should be separated by a newline character. There must be no other text than the list.
"""

# %%
subtopic_list = responses.choices[0].message.content.split(",")

# %%
def generate_instructions(client, sub_topic, n_instructions):
    print(f"Generating Instructions for {sub_topic}.")
    prompt = INSTRUCTION_PROMPT_TEMPLATE.format(sub_topic=sub_topic, n_instructions=n_instructions)
    response = client.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "user",
             "content": prompt}
        ],
        temperature=0.2,
        top_p=0.7,
    )
    return response.choices[0].message.content

def instructions_generator(client, subtopic_list, n_instructions):
    instruction_list = [generate_instructions(client, subtopic, n_instructions) for subtopic in subtopic_list]
    return instruction_list

# %%
instruction_list = instructions_generator(client, subtopic_list, n_instructions)

instruction_list_formatted = []
for instruction_set in instruction_list:
    instruction_list_formatted.extend([instruction.strip() for instruction in instruction_set.split("\n") if instruction])
# Out:
# Generating Instructions for Data Retrieval.
# Generating Instructions for  Data Manipulation.
# Generating Instructions for  Data Definition.
# Generating Instructions for  Data Control.
# Generating Instructions for  Transaction Control.
# Generating Instructions for  Query Optimization.
# Generating Instructions for  Error Handling.
# Generating Instructions for  Security Management.
# Generating Instructions for  Index Management.
# Generating Instructions for  View Management.

# %% [markdown]
# The final result is a list of instructions that are ready to be paired with corresponding SQL queries, forming the foundation of the dataset.

# %%
instruction_list_formatted[:6]
# Out:
# ['Show me all the records from the customers table',
#  'Can you get me the names and emails of all users',
#  'I need to see the total number of orders placed',
#  'Could you list all products that are out of stock',
#  'How do I find the highest price in the products table',
#  'Can you pull the data for customers who made more than one purchase']

# %% [markdown]
# ## **Step 4: Generating Responses**
#
# Once we have our instructions ready, the next step is to generate the SQL commands that correspond to each of those instructions. The idea is to take each natural language instruction and get a precise SQL query as the response.
#
# - **Response Prompt Template:** We define a prompt template that asks the model to generate the SQL command based on a given instruction. The model is specifically instructed to provide only the SQL query, with no additional explanation or text. This ensures that the response is concise and strictly focused on the SQL command.
#
# - **Pairing Instructions with Responses:** After generating the SQL responses, each instruction is paired with its corresponding SQL command. This pairing is essential for creating a comprehensive instruction-response dataset that can be used for training or testing AI models.
#
#
# This step ensures that we have both the natural language instructions and their corresponding SQL responses, ready for dataset construction and further use.

# %%
RESPONSE_PROMPT_TEMPLATE = """\
Given a question/instruction related to SQL, generate only the SQL command without any explanatory text or additional information.

The user prompt is: {instruction}
"""

# %%
def generate_responses(client, instruction):
    prompt = RESPONSE_PROMPT_TEMPLATE.format(instruction=instruction)
    response = client.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "user",
             "content": prompt}
        ],
        temperature=0.2,
        top_p=0.7,
        max_tokens=60,
    )
    return response.choices[0].message.content


def response_generator(client, instruction_list):
    response_list = [generate_responses(client, instruction) for instruction in instruction_list]
    return response_list

# %%
instruction_response_list = response_generator(client, instruction_list_formatted)

instruction_response_pair_list = []
for instruction, response in zip(instruction_list_formatted, instruction_response_list):
    instruction_response_pair_list.append(
        {
            "instruction": instruction,
            "responses": response,
        }
    )

# %% [markdown]
# The outcome is a list of instruction-response pairs, where each entry contains a user instruction and the corresponding SQL command.

# %%
instruction_response_pair_list
# Out:
# [{'instruction': 'Show me all the records from the customers table',
#   'responses': 'SELECT * FROM customers;'},
#  {'instruction': 'Can you get me the names and emails of all users',
#   'responses': 'SELECT name, email FROM users;'},
#  {'instruction': 'I need to see the total number of orders placed',
#   'responses': 'SELECT COUNT(*) AS total_orders FROM orders;'},
#  {'instruction': 'Could you list all products that are out of stock',
#   'responses': 'SELECT * FROM products WHERE stock = 0;'},
#  {'instruction': 'How do I find the highest price in the products table',
#   'responses': 'SELECT MAX(price) FROM products;'},
#  {'instruction': 'Can you pull the data for customers who made more than one purchase',
#   'responses': '```sql\nSELECT customer_id, COUNT(*) AS purchase_count\nFROM purchases\nGROUP BY customer_id\nHAVING COUNT(*) > 1;\n```'},
#  {'instruction': 'I want to see the average order amount',
#   'responses': 'SELECT AVG(order_amount) FROM orders;'},
#  {'instruction': 'How can I get a list of all unique cities from the addresses table',
#   'responses': 'SELECT DISTINCT city FROM addresses'},
#  {'instruction': 'Can you show me the last 10 orders placed',
#   'responses': 'SELECT * FROM orders ORDER BY order_date DESC LIMIT 10;'},
#  {'instruction': 'I need the names of customers who have not placed any orders',
#   'responses': 'SELECT name FROM customers WHERE customer_id NOT IN (SELECT customer_id FROM orders)'},
#  {'instruction': 'How do I retrieve the first 5 rows from the users table',
#   'responses': 'SELECT * FROM users LIMIT 5;'},
#  {'instruction': 'Can you give me the total sales for each product',
#   'responses': 'SELECT product_id, SUM(sales) AS total_sales FROM sales GROUP BY product_id;'},
#  {'instruction': 'I want to see the number of orders per month',
#   'responses': "SELECT DATE_TRUNC('month', order_date) AS month, COUNT(*) AS order_count FROM orders GROUP BY DATE_TRUNC('month', order_date) ORDER BY month;"},
#  {'instruction': 'Could you find the lowest price in the products table',
#   'responses': 'SELECT MIN(price) FROM products;'},
#  {'instruction': 'How can I get the count of customers in each city',
#   'responses': '```sql\nSELECT city, COUNT(*) AS customer_count\nFROM customers\nGROUP BY city;\n```'},
#  {'instruction': 'Can you list the products that have been ordered more than 10 times',
#   'responses': 'SELECT product_name FROM orders INNER JOIN order_items ON orders.order_id = order_items.order_id INNER JOIN products ON order_items.product_id = products.product_id GROUP BY product_name HAVING COUNT(order_items.order_id) > 10;'},
#  {'instruction': 'I need the names of customers who live in New York',
#   'responses': "SELECT name FROM customers WHERE city = 'New York'"},
#  {'instruction': 'How do I see the details of orders placed on a specific date',
#   'responses': "SELECT * FROM orders WHERE order_date = '2023-10-01';"},
#  {'instruction': 'Can you show me the total revenue by customer',
#   'responses': 'SELECT customer_id, SUM(revenue) AS total_revenue FROM orders GROUP BY customer_id;'},
#  {'instruction': 'I want to know the number of unique products in the inventory',
#   'responses': 'SELECT COUNT(DISTINCT product_id) FROM inventory;'},
#  {'instruction': 'Show me how to add a new column to an existing table',
#   'responses': 'ALTER TABLE table_name ADD column_name data_type;'},
#  {'instruction': 'Can you explain how to delete a row from a table',
#   'responses': 'DELETE FROM table_name WHERE condition;'},
#  {'instruction': 'How do I update the value in a specific column for all rows',
#   'responses': 'UPDATE table_name SET column_name = new_value;'},
#  {'instruction': 'I need to copy data from one table to another what SQL command should I use',
#   'responses': 'INSERT INTO target_table SELECT * FROM source_table;'},
#  {'instruction': 'Can you give me an example of how to insert data into a table',
#   'responses': 'INSERT INTO table_name (column1, column2, column3) VALUES (value1, value2, value3);'},
#  {'instruction': 'How can I change the data type of a column in a table',
#   'responses': 'ALTER TABLE table_name MODIFY column_name new_data_type;'},
#  {'instruction': 'What is the command to rename a table',
#   'responses': 'ALTER TABLE old_table_name RENAME TO new_table_name;'},
#  {'instruction': 'How do I merge two tables together',
#   'responses': '```sql\nSELECT * FROM table1\nINNER JOIN table2\nON table1.common_column = table2.common_column;\n```'},
#  {'instruction': 'Can you show me how to filter out rows that have duplicate values in a specific column',
#   'responses': 'SELECT DISTINCT column_name FROM table_name;'},
#  {'instruction': 'I want to sort the data in a table by a specific column how do I do that',
#   'responses': 'SELECT * FROM table_name ORDER BY column_name;'},
#  {'instruction': 'How can I select only certain columns from a table',
#   'responses': 'SELECT column1, column2, column3 FROM table_name;'},
#  {'instruction': 'What is the command to remove a column from a table',
#   'responses': 'ALTER TABLE table_name DROP COLUMN column_name;'},
#  {'instruction': 'Can you help me with a query to find the maximum value in a column',
#   'responses': 'SELECT MAX(column_name) FROM table_name;'},
#  {'instruction': 'How do I count the number of rows in a table',
#   'responses': 'SELECT COUNT(*) FROM table_name;'},
#  {'instruction': 'I need to calculate the average of a column how do I write the SQL command',
#   'responses': 'SELECT AVG(column_name) FROM table_name;'},
#  {'instruction': 'Can you show me how to group data by a column and get the sum of another column',
#   'responses': 'SELECT column1, SUM(column2) FROM table_name GROUP BY column1;'},
#  {'instruction': 'How do I join two tables based on a common column',
#   'responses': 'SELECT * FROM table1 JOIN table2 ON table1.common_column = table2.common_column;'},
#  {'instruction': 'What is the command to check if a column exists in a table',
#   'responses': "SELECT column_name FROM information_schema.columns WHERE table_name = 'your_table_name' AND column_name = 'your_column_name';"},
#  {'instruction': 'I want to update multiple columns in a single row how do I do that',
#   'responses': 'UPDATE table_name SET column1 = value1, column2 = value2 WHERE condition;'},
#  {'instruction': 'Can you give me an example of how to use the WHERE clause to filter data',
#   'responses': "SELECT * FROM table_name WHERE column_name = 'value';"},
#  {'instruction': 'Create a table for storing customer information',
#   'responses': 'CREATE TABLE customers (\n    customer_id INT PRIMARY KEY,\n    first_name VARCHAR(50),\n    last_name VARCHAR(50),\n    email VARCHAR(100),\n    phone_number VARCHAR(15),\n    address VARCHAR(255)\n);'},
#  {'instruction': 'Add a column to an existing table for product prices',
#   'responses': 'ALTER TABLE products ADD COLUMN price DECIMAL(10, 2);'},
#  {'instruction': 'Remove a column from a table that is no longer needed',
#   'responses': 'ALTER TABLE table_name DROP COLUMN column_name;'},
#  {'instruction': 'Change the data type of a column in a table',
#   'responses': 'ALTER TABLE table_name MODIFY column_name new_data_type;'},
#  {'instruction': 'Rename a table to a more descriptive name',
#   'responses': 'ALTER TABLE old_table_name RENAME TO new_table_name;'},
#  {'instruction': 'Delete a table that is no longer in use',
#   'responses': 'DROP TABLE table_name;'},
#  {'instruction': 'Set a column as the primary key for a table',
#   'responses': 'ALTER TABLE table_name ADD PRIMARY KEY (column_name);'},
#  {'instruction': 'Add a foreign key to link two tables together',
#   'responses': 'ALTER TABLE table_name1 ADD FOREIGN KEY (column_name) REFERENCES table_name2(column_name);'},
#  {'instruction': 'Create an index on a column to speed up queries',
#   'responses': 'CREATE INDEX idx_column_name ON table_name (column_name);'},
#  {'instruction': 'Drop an index from a column that is rarely used',
#   'responses': 'DROP INDEX index_name ON table_name;'},
#  {'instruction': 'Alter a table to add multiple columns at once',
#   'responses': 'ALTER TABLE table_name ADD (column1 datatype, column2 datatype, column3 datatype);'},
#  {'instruction': 'Change the name of a column to be more clear',
#   'responses': 'ALTER TABLE table_name RENAME COLUMN old_column_name TO new_column_name;'},
#  {'instruction': 'Add a unique constraint to a column to avoid duplicates',
#   'responses': 'ALTER TABLE table_name ADD CONSTRAINT constraint_name UNIQUE (column_name);'},
#  {'instruction': 'Remove a unique constraint from a column',
#   'responses': 'ALTER TABLE table_name DROP CONSTRAINT constraint_name;'},
#  {'instruction': 'Create a view to simplify complex queries',
#   'responses': 'CREATE VIEW simplified_view AS SELECT column1, column2, column3 FROM complex_table WHERE condition;'},
#  {'instruction': 'Drop a view that is no longer needed',
#   'responses': 'DROP VIEW view_name;'},
#  {'instruction': 'Add a check constraint to ensure data integrity',
#   'responses': 'ALTER TABLE table_name ADD CONSTRAINT constraint_name CHECK (column_name condition);'},
#  {'instruction': 'Remove a check constraint that is no longer necessary',
#   'responses': 'ALTER TABLE table_name DROP CONSTRAINT constraint_name;'},
#  {'instruction': 'Create a new database for a project',
#   'responses': 'CREATE DATABASE project_db;'},
#  {'instruction': 'Delete a database that is no longer required',
#   'responses': 'DROP DATABASE database_name;'},
#  {'instruction': 'Show me how to give someone access to a database',
#   'responses': "GRANT ALL PRIVILEGES ON database_name.* TO 'username'@'localhost';"},
#  {'instruction': 'Can you explain how to revoke permissions from a user in simple terms',
#   'responses': "REVOKE ALL PRIVILEGES ON *.* FROM 'username'@'host';"},
#  {'instruction': 'How do I check what permissions a user has',
#   'responses': "SELECT * FROM information_schema.user_privileges WHERE grantee = 'user_name'@'host_name';"},
#  {'instruction': 'I need to grant select insert and update permissions to a user',
#   'responses': "GRANT SELECT, INSERT, UPDATE ON *.* TO 'username'@'localhost';"},
#  {'instruction': 'Can you help me understand how to use GRANT for a specific table',
#   'responses': "GRANT SELECT, INSERT, UPDATE, DELETE ON database_name.table_name TO 'username'@'host';"},
#  {'instruction': 'How do I allow a user to create new tables',
#   'responses': 'GRANT CREATE TABLE TO username;'},
#  {'instruction': 'What is the command to deny a user from deleting records',
#   'responses': "REVOKE DELETE ON *.* FROM 'username'@'host';"},
#  {'instruction': 'Can you show me how to grant all privileges to a user',
#   'responses': "GRANT ALL PRIVILEGES ON *.* TO 'username'@'localhost';"},
#  {'instruction': 'How do I remove all permissions from a user',
#   'responses': "REVOKE ALL PRIVILEGES, GRANT OPTION FROM 'username'@'host';"},
#  {'instruction': 'I want to give a user the ability to grant permissions to others',
#   'responses': "GRANT GRANT OPTION ON *.* TO 'username'@'localhost';"},
#  {'instruction': 'Can you explain the difference between GRANT and REVOKE',
#   'responses': '```sql\n-- GRANT example\nGRANT SELECT, INSERT ON database.table TO user;\n\n-- REVOKE example\nREVOKE SELECT, INSERT ON database.table FROM user;\n```'},
#  {'instruction': 'How do I limit a users access to only certain columns in a table',
#   'responses': 'GRANT SELECT (column1, column2) ON table_name TO user_name;'},
#  {'instruction': 'What is the syntax to revoke a specific privilege from a user',
#   'responses': 'REVOKE privilege_name ON object_name FROM user_name;'},
#  {'instruction': 'Can you help me set up a read only user',
#   'responses': "```sql\nCREATE USER 'readonlyuser'@'localhost' IDENTIFIED BY 'password';\nGRANT SELECT ON *.* TO 'readonlyuser'@'localhost';\nFLUSH PRIVILEGES;\n```"},
#  {'instruction': 'How do I grant permissions to a group of users',
#   'responses': "GRANT ALL PRIVILEGES ON *.* TO 'group_name'@'localhost';"},
#  {'instruction': 'I need to know how to change a users password',
#   'responses': "UPDATE users SET password = 'new_password' WHERE username = 'user_name';"},
#  {'instruction': 'Can you show me how to log user activities',
#   'responses': '```sql\nCREATE TABLE user_activities (\n    activity_id INT AUTO_INCREMENT PRIMARY KEY,\n    user_id INT NOT NULL,\n    activity_type VARCHAR(50) NOT NULL,\n    activity_details TEXT,\n    activity_time TIMESTAMP DEFAULT CURRENT_TIMESTAMP\n);\n\nINSERT INTO user_activities (user_id, activity_type,'},
#  {'instruction': 'How do I prevent a user from accessing a database',
#   'responses': 'REVOKE ALL PRIVILEGES ON DATABASE * FROM username;'},
#  {'instruction': 'What is the command to see all the users in a database',
#   'responses': 'SELECT user FROM mysql.user;'},
#  {'instruction': 'Can you help me understand roles in SQL data control',
#   'responses': '```sql\nSELECT role_name, role_type, grantor, grantee \nFROM information_schema.enabled_roles \nWHERE grantee = CURRENT_USER;\n```'},
#  {'instruction': 'How to start a transaction in SQL',
#   'responses': 'BEGIN TRANSACTION;'},
#  {'instruction': 'Can you show me how to commit changes in a transaction',
#   'responses': 'COMMIT;'},
#  {'instruction': 'How do I roll back a transaction if something goes wrong',
#   'responses': 'ROLLBACK;'},
#  {'instruction': 'What is the syntax for beginning a transaction',
#   'responses': 'BEGIN TRANSACTION;'},
#  {'instruction': 'Can you explain how to use savepoints in transactions',
#   'responses': '```sql\nBEGIN TRANSACTION;\n\n-- Perform some SQL operations\nINSERT INTO table_name (column1, column2) VALUES (value1, value2);\n\n-- Set a savepoint\nSAVEPOINT my_savepoint;\n\n-- Perform more SQL operations\nUPDATE table_name SET column1 = value3 WHERE condition'},
#  {'instruction': 'How do I undo changes made in a transaction',
#   'responses': 'ROLLBACK;'},
#  {'instruction': 'What is the command to end a transaction successfully',
#   'responses': 'COMMIT;'},
#  {'instruction': 'Can you give an example of a transaction with a rollback',
#   'responses': 'BEGIN TRANSACTION;\n\nUPDATE accounts SET balance = balance - 100 WHERE account_id = 1;\nUPDATE accounts SET balance = balance + 100 WHERE account_id = 2;\n\nROLLBACK;'},
#  {'instruction': 'How to handle errors during a transaction',
#   'responses': 'BEGIN TRY\n    BEGIN TRANSACTION;\n    -- SQL statements go here\n    COMMIT TRANSACTION;\nEND TRY\nBEGIN CATCH\n    ROLLBACK TRANSACTION;\n    -- Optionally, log the error or handle it as needed\nEND CATCH;'},
#  {'instruction': 'What happens if I dont commit a transaction',
#   'responses': 'ROLLBACK;'},
#  {'instruction': 'How do I check if a transaction is still open',
#   'responses': "SELECT * FROM information_schema.innodb_trx WHERE trx_id = 'your_transaction_id';"},
#  {'instruction': 'Can you show me how to use transactions for multiple updates',
#   'responses': '```sql\nBEGIN TRANSACTION;\n\nUPDATE table1 SET column1 = value1 WHERE condition1;\nUPDATE table2 SET column2 = value2 WHERE condition2;\n\nCOMMIT;\n```'},
#  {'instruction': 'What is the difference between commit and rollback',
#   'responses': "SELECT 'COMMIT saves the current transaction, making all changes permanent. ROLLBACK undoes all changes made in the current transaction.' AS Explanation;"},
#  {'instruction': 'How to use transactions to ensure data integrity',
#   'responses': 'BEGIN TRANSACTION;\n\n-- SQL commands to modify data\n\nCOMMIT;'},
#  {'instruction': 'Can you explain the concept of transaction control',
#   'responses': 'BEGIN TRANSACTION;\n-- SQL statements\nCOMMIT;\n-- or\nROLLBACK;'},
#  {'instruction': 'How do I create a savepoint in a transaction',
#   'responses': 'SAVEPOINT my_savepoint;'},
#  {'instruction': 'What is the purpose of a savepoint in a transaction',
#   'responses': 'SAVEPOINT my_savepoint;'},
#  {'instruction': 'How to recover data using transaction control',
#   'responses': 'ROLLBACK;'},
#  {'instruction': 'Can you give an example of a transaction with multiple savepoints',
#   'responses': "```sql\nBEGIN TRANSACTION;\n\nSAVEPOINT sp1;\nINSERT INTO orders (customer_id, order_date, total) VALUES (1, '2023-01-01', 100);\n\nSAVEPOINT sp2;\nUPDATE orders SET total = 150 WHERE customer"},
#  {'instruction': 'How to manage transactions in a complex database operation',
#   'responses': 'BEGIN TRANSACTION;\n\n-- SQL commands for complex database operations go here\n\nCOMMIT;'},
#  {'instruction': 'How can I make my SQL queries run faster',
#   'responses': 'EXPLAIN PLAN FOR SELECT * FROM table_name;'},
#  {'instruction': 'Can you help me optimize this query for better performance',
#   'responses': "```sql\nEXPLAIN ANALYZE SELECT * FROM your_table WHERE your_column = 'your_value';\n```"},
#  {'instruction': 'Im trying to speed up my database searches can you help',
#   'responses': "EXPLAIN ANALYZE SELECT * FROM your_table WHERE your_column = 'your_value';"},
#  {'instruction': 'What are some tips for writing efficient SQL queries',
#   'responses': "SELECT 'Use indexes', 'Avoid SELECT *', 'Use JOINs wisely', 'Limit result sets', 'Optimize subqueries', 'Use appropriate data types', 'Keep transactions short' AS Tips FOR Efficient_SQL_Queries;"},
#  {'instruction': 'How do I reduce the time it takes to run a query',
#   'responses': 'EXPLAIN ANALYZE SELECT * FROM table_name;'},
#  {'instruction': 'Can you explain how to use indexes to speed up queries',
#   'responses': '```sql\nCREATE INDEX idx_column_name ON table_name (column_name);\n```'},
#  {'instruction': 'I heard using the right data types can make queries faster how',
#   'responses': "SELECT * FROM information_schema.columns WHERE table_name = 'your_table' AND data_type IN ('int', 'bigint', 'smallint', 'tinyint', 'decimal', 'numeric', 'float', 'real', 'double precision', 'date', 'timestamp', 'time', 'interval',"},
#  {'instruction': 'How can I check if my query is optimized',
#   'responses': 'EXPLAIN PLAN FOR YOUR_QUERY;'},
#  {'instruction': 'What are common mistakes that slow down SQL queries',
#   'responses': "SELECT * FROM common_mistakes WHERE topic = 'SQL Performance' AND mistake_type = 'Query Optimization'"},
#  {'instruction': 'How do I avoid using SELECT in my queries to improve speed',
#   'responses': '```sql\nCREATE VIEW my_view AS SELECT * FROM my_table;\nSELECT * FROM my_view;\n```'},
#  {'instruction': 'Can you show me how to use EXPLAIN to optimize my query',
#   'responses': 'EXPLAIN SELECT * FROM table_name;'},
#  {'instruction': 'What is the best way to join tables for performance',
#   'responses': 'SELECT * FROM table1 INNER JOIN table2 ON table1.id = table2.id;'},
#  {'instruction': 'How can I optimize queries that involve large datasets',
#   'responses': '```sql\nEXPLAIN ANALYZE SELECT * FROM large_table WHERE condition;\nCREATE INDEX idx_large_table_column ON large_table(column);\nVACUUM ANALYZE large_table;\n```'},
#  {'instruction': 'Im having trouble with slow query performance what can I do',
#   'responses': 'EXPLAIN ANALYZE SELECT * FROM your_table WHERE your_condition;'},
#  {'instruction': 'Can you give me some advice on optimizing queries for read heavy applications',
#   'responses': "SELECT * FROM table_name WHERE indexed_column = 'value'; CREATE INDEX idx_column ON table_name (column_to_index); ANALYZE table_name; SET query_cache_type = DEMAND; SHOW PROFILES; EXPLAIN SELECT * FROM table_name WHERE column = 'value'; OPTIMIZE TABLE table_name"},
#  {'instruction': 'How do I optimize queries that are used frequently',
#   'responses': 'CREATE INDEX idx_column_name ON table_name (column_name);'},
#  {'instruction': 'What are some best practices for query optimization',
#   'responses': "SELECT * FROM best_practices WHERE topic = 'query_optimization' ORDER BY relevance DESC LIMIT 10;"},
#  {'instruction': 'How can I optimize my query to use less memory',
#   'responses': 'EXPLAIN ANALYZE SELECT * FROM table_name WHERE condition;'},
#  {'instruction': 'Can you help me understand how to optimize subqueries',
#   'responses': 'SELECT * FROM table_name WHERE column_name IN (SELECT column_name FROM another_table WHERE condition) -- Optimize by ensuring indexes on column_name in both tables and considering JOINs for large datasets. However, no additional text or explanation is provided as per instruction. For the sake of compliance, here is'},
#  {'instruction': 'What are some tools I can use to optimize my SQL queries',
#   'responses': "SELECT tool_name, description FROM optimization_tools WHERE category = 'SQL' ORDER BY popularity DESC LIMIT 10;"},
#  {'instruction': 'How do I optimize queries that involve multiple tables',
#   'responses': '```sql\nEXPLAIN ANALYZE SELECT * FROM table1 JOIN table2 ON table1.id = table2.id;\n```'},
#  {'instruction': 'How to handle errors when running SQL queries',
#   'responses': 'BEGIN TRY\n    -- SQL Query goes here\nEND TRY\nBEGIN CATCH\n    SELECT \n        ERROR_NUMBER() AS ErrorNumber,\n        ERROR_SEVERITY() AS ErrorSeverity,\n        ERROR_STATE() AS ErrorState,\n        ERROR_PROCEDURE() AS ErrorProcedure,\n        ERROR_LINE() AS'},
#  {'instruction': 'What do I do if my SQL command fails',
#   'responses': "SELECT * FROM information_schema.tables WHERE table_schema = 'your_database_name';"},
#  {'instruction': 'Can you show me how to catch errors in SQL',
#   'responses': 'BEGIN TRY\n    -- SQL statements go here\nEND TRY\nBEGIN CATCH\n    SELECT \n        ERROR_NUMBER() AS ErrorNumber,\n        ERROR_SEVERITY() AS ErrorSeverity,\n        ERROR_STATE() AS ErrorState,\n        ERROR_PROCEDURE() AS ErrorProcedure,\n        ERROR_LINE() AS'},
#  {'instruction': 'How can I prevent common SQL errors',
#   'responses': "```sql\nSET sql_mode = 'STRICT_ALL_TABLES';\n```"},
#  {'instruction': 'What are some tips for debugging SQL errors',
#   'responses': "SELECT * FROM tips WHERE category = 'SQL Debugging'"},
#  {'instruction': 'How to use try catch in SQL',
#   'responses': 'BEGIN TRY\n    -- SQL statements to try\nEND TRY\nBEGIN CATCH\n    -- SQL statements to handle errors\nEND CATCH;'},
#  {'instruction': 'Can you explain error handling in SQL for beginners',
#   'responses': 'SELECT * FROM table_name WHERE condition ON EXCEPTION HANDLE error_type;'},
#  {'instruction': 'What is the best way to manage errors in SQL',
#   'responses': 'CREATE PROCEDURE ErrorHandler\nAS\nBEGIN\n    BEGIN TRY\n        -- SQL statements go here\n    END TRY\n    BEGIN CATCH\n        SELECT \n            ERROR_NUMBER() AS ErrorNumber,\n            ERROR_SEVERITY() AS ErrorSeverity,\n            ERROR_STATE() AS ErrorState,\n            ERROR'},
#  {'instruction': 'How do I get error messages in SQL',
#   'responses': 'SELECT @@ERROR, ERROR_MESSAGE(), ERROR_LINE(), ERROR_PROCEDURE(), ERROR_STATE(), ERROR_SEVERITY();'},
#  {'instruction': 'What should I do when I get an unexpected result in SQL',
#   'responses': 'SELECT * FROM table_name WHERE condition; -- Ensure your query is correct and the condition matches your expectation. Check for typos, correct table and column names, and proper use of SQL functions.'},
#  {'instruction': 'How can I make my SQL code more robust against errors',
#   'responses': '```sql\nBEGIN TRY\n    -- Your SQL code here\nEND TRY\nBEGIN CATCH\n    SELECT \n        ERROR_NUMBER() AS ErrorNumber,\n        ERROR_SEVERITY() AS ErrorSeverity,\n        ERROR_STATE() AS ErrorState,\n        ERROR_PROCEDURE() AS ErrorProcedure,\n        ERROR'},
#  {'instruction': 'Can you give examples of common SQL errors and how to fix them',
#   'responses': "```sql\n-- Example 1: Incorrect column name\n-- Error: SELECT * FROM users WHERE usre_name = 'John';\n-- Fix: SELECT * FROM users WHERE user_name = 'John';\n\n-- Example 2: Missing comma between columns\n-- Error: SELECT id name FROM users;\n"},
#  {'instruction': 'How to use error codes in SQL',
#   'responses': 'SELECT SQLERRM, SQLCODE FROM DUAL;'},
#  {'instruction': 'What are the most common SQL errors and how to avoid them',
#   'responses': 'SELECT error_code, error_message, COUNT(*) AS frequency \nFROM sql_errors \nGROUP BY error_code, error_message \nORDER BY frequency DESC;'},
#  {'instruction': 'How can I log errors in SQL',
#   'responses': 'CREATE TABLE ErrorLog (\n    ErrorID INT IDENTITY(1,1) PRIMARY KEY,\n    ErrorTime DATETIME DEFAULT CURRENT_TIMESTAMP,\n    ErrorMessage NVARCHAR(4000),\n    ErrorSeverity INT,\n    ErrorState INT\n);\n\nINSERT INTO ErrorLog (ErrorMessage, ErrorSeverity, Error'},
#  {'instruction': 'Can you explain the difference between error and exception in SQL',
#   'responses': "SELECT 'This query does not provide an explanation but is an example of an SQL command.' AS Note;"},
#  {'instruction': 'How to handle division by zero errors in SQL',
#   'responses': 'SELECT COALESCE(NULLIF(a, 0), 1) AS denominator, b / COALESCE(NULLIF(a, 0), 1) AS result FROM your_table;'},
#  {'instruction': 'What is the best practice for error handling in SQL',
#   'responses': 'BEGIN TRY\n    -- SQL statements go here\nEND TRY\nBEGIN CATCH\n    SELECT \n        ERROR_NUMBER() AS ErrorNumber,\n        ERROR_SEVERITY() AS ErrorSeverity,\n        ERROR_STATE() AS ErrorState,\n        ERROR_PROCEDURE() AS ErrorProcedure,\n        ERROR_LINE() AS'},
#  {'instruction': 'How can I test my SQL code for potential errors',
#   'responses': "SELECT * FROM information_schema.routines WHERE routine_name = 'your_procedure_name' AND routine_type = 'PROCEDURE'"},
#  {'instruction': 'Can you recommend a resource for learning SQL error handling',
#   'responses': "SELECT resource_name, resource_link FROM resources WHERE topic = 'SQL Error Handling' AND resource_type = 'tutorial' ORDER BY rating DESC LIMIT 1;"},
#  {'instruction': 'How to set up a password for a user in SQL',
#   'responses': "ALTER USER 'username'@'localhost' IDENTIFIED BY 'new_password';"},
#  {'instruction': 'Can you show me how to create a new user with limited access',
#   'responses': "CREATE USER 'newuser'@'localhost' IDENTIFIED BY 'password';\nGRANT SELECT, INSERT ON database_name.* TO 'newuser'@'localhost';"},
#  {'instruction': 'I need to revoke all privileges from a user',
#   'responses': "REVOKE ALL PRIVILEGES, GRANT OPTION FROM 'username'@'host';"},
#  {'instruction': 'How do I grant select privileges on a specific table',
#   'responses': 'GRANT SELECT ON table_name TO user_name;'},
#  {'instruction': 'Can you help me change a users password',
#   'responses': "UPDATE users SET password = 'new_password' WHERE username = 'user_name';"},
#  {'instruction': 'I want to see all the users in the database',
#   'responses': 'SELECT * FROM users;'},
#  {'instruction': 'How can I check the current users privileges',
#   'responses': 'SHOW GRANTS FOR CURRENT_USER();'},
#  {'instruction': 'Can you explain how to enable SSL for database connections',
#   'responses': "```sql\nALTER SYSTEM SET ssl = 'on';\n```"},
#  {'instruction': 'I need to create a role with specific permissions',
#   'responses': 'CREATE ROLE new_role;\nGRANT SELECT, INSERT, UPDATE ON database_name.table_name TO new_role;'},
#  {'instruction': 'How do I assign a role to a user',
#   'responses': 'GRANT ROLE role_name TO user_name;'},
#  {'instruction': 'Can you show me how to drop a user safely',
#   'responses': "DROP USER IF EXISTS 'username'@'host';"},
#  {'instruction': 'How can I log failed login attempts',
#   'responses': 'CREATE TABLE FailedLogins (\n    id INT AUTO_INCREMENT PRIMARY KEY,\n    username VARCHAR(255) NOT NULL,\n    attempt_time DATETIME NOT NULL,\n    ip_address VARCHAR(45) NOT NULL\n);\n\nINSERT INTO FailedLogins (username, attempt_time, ip_address) VALUES'},
#  {'instruction': 'I want to set up a firewall rule for my database',
#   'responses': "```sql\nCREATE FIREWALL RULE myFirewallRule WITH (START_IP = '0.0.0.0', END_IP = '255.255.255.255');\n```"},
#  {'instruction': 'How do I encrypt data in the database',
#   'responses': "```sql\nUPDATE table_name SET column_name = AES_ENCRYPT(column_name, 'encryption_key');\n```"},
#  {'instruction': 'Can you help me audit user activities',
#   'responses': 'SELECT * FROM user_activities;'},
#  {'instruction': 'I need to create a read only user for reporting',
#   'responses': "CREATE USER 'report_user'@'localhost' IDENTIFIED BY 'password';\nGRANT SELECT ON *.* TO 'report_user'@'localhost';"},
#  {'instruction': 'How can I prevent SQL injection attacks',
#   'responses': "PREPARE stmt FROM 'SELECT * FROM users WHERE username = ? AND password = ?';\nEXECUTE stmt USING @username, @password;\nDEALLOCATE PREPARE stmt;"},
#  {'instruction': 'Can you explain how to use row level security',
#   'responses': '```sql\nCREATE POLICY example_policy ON table_name\nAS PERMISSIVE\nFOR ALL\nTO public\nUSING (current_user = user_column);\n```'},
#  {'instruction': 'I want to set up a secure connection to the database from my application',
#   'responses': "```sql\nCREATE USER 'appuser'@'localhost' IDENTIFIED BY 'securepassword';\nGRANT ALL PRIVILEGES ON mydatabase.* TO 'appuser'@'localhost';\nFLUSH PRIVILEGES;\n```"},
#  {'instruction': 'How do I manage user sessions in the database',
#   'responses': "CREATE TABLE user_sessions (\n    session_id VARCHAR(255) PRIMARY KEY,\n    user_id INT NOT NULL,\n    start_time TIMESTAMP DEFAULT CURRENT_TIMESTAMP,\n    end_time TIMESTAMP NULL,\n    status VARCHAR(50) DEFAULT 'active'\n);"},
#  {'instruction': 'Create an index for the users table on the email column',
#   'responses': 'CREATE INDEX idx_users_email ON users (email);'},
#  {'instruction': 'Add an index to speed up searches on the product name',
#   'responses': 'CREATE INDEX idx_product_name ON products (product_name);'},
#  {'instruction': 'Remove the index from the orders table that is no longer needed',
#   'responses': 'DROP INDEX IF EXISTS index_name ON orders;'},
#  {'instruction': 'I need to make sure the index on the customer ID is working properly',
#   'responses': '```sql\nSELECT * FROM customer WHERE customer_id = 12345;\n```'},
#  {'instruction': 'Can you check if there is an index on the date column',
#   'responses': "```sql\nSELECT \n    t.table_schema, \n    t.table_name, \n    t.column_name, \n    t.index_name \nFROM \n    information_schema.statistics t \nWHERE \n    t.table_schema = 'your_database_name' \n    AND t.table_name = 'your_table_name'"},
#  {'instruction': 'I want to create a unique index on the username field',
#   'responses': 'CREATE UNIQUE INDEX idx_username ON users (username);'},
#  {'instruction': 'How do I drop an index that is causing issues',
#   'responses': 'DROP INDEX index_name ON table_name;'},
#  {'instruction': 'Add a composite index on the first name and last name columns',
#   'responses': 'CREATE INDEX idx_first_last_name ON users (first_name, last_name);'},
#  {'instruction': 'Improve query performance by adding an index to the most searched column',
#   'responses': 'CREATE INDEX idx_most_searched_column ON table_name (most_searched_column);'},
#  {'instruction': 'Can you help me create an index that will not slow down inserts',
#   'responses': 'CREATE INDEX idx_name ON table_name (column_name) WHERE condition;'},
#  {'instruction': 'I heard about full text indexes can we use one for the article content',
#   'responses': 'CREATE FULLTEXT INDEX idx_article_content ON articles (content);'},
#  {'instruction': 'Check if the index is being used in the query execution plan',
#   'responses': "EXPLAIN (ANALYZE, VERBOSE) SELECT * FROM table_name WHERE column_name = 'value';"},
#  {'instruction': 'I need to rebuild an index that has become fragmented',
#   'responses': 'ALTER INDEX [index_name] ON [table_name] REBUILD;'},
#  {'instruction': 'How can I see all the indexes on a specific table',
#   'responses': "```sql\nSELECT * FROM information_schema.statistics WHERE table_name = 'your_table_name';\n```"},
#  {'instruction': 'Create an index that will help with sorting results faster',
#   'responses': 'CREATE INDEX idx_sorting ON table_name (column_name);'},
#  {'instruction': 'Can you explain how to create a covering index',
#   'responses': 'CREATE INDEX idx_covering ON table_name (column1, column2, column3);'},
#  {'instruction': 'I want to add an index but Im not sure which column to choose',
#   'responses': "```sql\nSELECT COLUMN_NAME \nFROM INFORMATION_SCHEMA.STATISTICS \nWHERE TABLE_SCHEMA = 'your_database_name' \nAND TABLE_NAME = 'your_table_name';\n```"},
#  {'instruction': 'What is the best practice for naming indexes',
#   'responses': "SELECT * FROM best_practices WHERE topic = 'naming_indexes'"},
#  {'instruction': 'Im getting slow query results can adding an index help',
#   'responses': '```sql\nCREATE INDEX idx_column_name ON table_name (column_name);\n```'},
#  {'instruction': 'How do I know if my database needs more indexes',
#   'responses': 'SELECT * FROM pg_stat_user_tables WHERE seq_scan > 0 AND idx_scan = 0;'},
#  {'instruction': 'Create a view that shows only the active users',
#   'responses': "SELECT * FROM users WHERE status = 'active';"},
#  {'instruction': 'I need a view that combines data from users and their orders',
#   'responses': 'CREATE VIEW user_orders AS SELECT users.user_id, users.name, orders.order_id, orders.order_date, orders.total_amount FROM users JOIN orders ON users.user_id = orders.user_id;'},
#  {'instruction': 'Can you make a view that filters out inactive accounts',
#   'responses': "CREATE VIEW ActiveAccounts AS SELECT * FROM Accounts WHERE status = 'active';"},
#  {'instruction': 'How do I create a view that updates when the original data changes',
#   'responses': 'CREATE VIEW view_name AS SELECT * FROM original_table;'},
#  {'instruction': 'Show me how to delete a view I no longer need',
#   'responses': 'DROP VIEW view_name;'},
#  {'instruction': 'I want to create a view that summarizes sales by month',
#   'responses': "CREATE VIEW SalesByMonth AS SELECT DATE_TRUNC('month', sale_date) AS Month, SUM(sale_amount) AS TotalSales FROM sales GROUP BY DATE_TRUNC('month', sale_date);"},
#  {'instruction': 'Can you help me create a view that hides sensitive information',
#   'responses': 'CREATE VIEW safe_user_info AS SELECT user_id, username, email FROM users WHERE active = 1;'},
#  {'instruction': 'I need a view that only shows the top 10 customers by purchase amount',
#   'responses': 'CREATE VIEW Top10CustomersByPurchase AS SELECT customer_id, SUM(purchase_amount) AS total_spent FROM purchases GROUP BY customer_id ORDER BY total_spent DESC LIMIT 10;'},
#  {'instruction': 'How can I rename a view I created earlier',
#   'responses': 'ALTER VIEW old_view_name RENAME TO new_view_name;'},
#  {'instruction': 'Can you explain how to create a simple view for my project',
#   'responses': 'CREATE VIEW simple_view AS SELECT column1, column2 FROM table_name;'},
#  {'instruction': 'I want to create a view that joins multiple tables together',
#   'responses': 'CREATE VIEW combined_view AS SELECT * FROM table1 JOIN table2 ON table1.id = table2.id JOIN table3 ON table2.id = table3.id;'},
#  {'instruction': 'How do I check if a view already exists in my database',
#   'responses': "SELECT * FROM information_schema.views WHERE table_schema = 'your_database_name' AND table_name = 'your_view_name';"},
#  {'instruction': 'Can you show me how to create a view with a complex query',
#   'responses': '```sql\nCREATE VIEW ComplexView AS\nSELECT a.column1, b.column2, c.column3\nFROM table1 a\nJOIN table2 b ON a.id = b.id\nJOIN table3 c ON b.id = c.id\nWHERE a.column1 > 100\nGROUP'},
#  {'instruction': 'I need a view that updates automatically when new data is added',
#   'responses': 'CREATE VIEW view_name AS SELECT * FROM table_name;'},
#  {'instruction': 'How do I create a view that only certain users can access',
#   'responses': 'CREATE VIEW restricted_view AS SELECT * FROM sensitive_table WHERE condition;\nGRANT SELECT ON restricted_view TO user1, user2;'},
#  {'instruction': 'Can you help me create a view that sorts data in a specific way',
#   'responses': 'CREATE VIEW sorted_data_view AS SELECT * FROM your_table_name ORDER BY your_column_name;'},
#  {'instruction': 'I want to create a view that includes a calculated field',
#   'responses': 'CREATE VIEW view_name AS SELECT column1, column2, (column1 * column2) AS calculated_field FROM table_name;'},
#  {'instruction': 'How do I create a view that filters data based on a condition',
#   'responses': 'CREATE VIEW filtered_data AS SELECT * FROM table_name WHERE condition;'},
#  {'instruction': 'Can you show me how to create a view that aggregates data',
#   'responses': '```sql\nCREATE VIEW aggregated_data AS\nSELECT column1, column2, SUM(column3) AS total\nFROM table_name\nGROUP BY column1, column2;\n```'},
#  {'instruction': 'I need a view that combines data from different databases',
#   'responses': 'CREATE VIEW combined_data_view AS \nSELECT * FROM database1.table1 \nJOIN database2.table2 ON database1.table1.id = database2.table2.id;'}]

# %% [markdown]
# ## **Step 5: Filtering the Data**
#
# Now Let's filter and refine the generated data. For this, we will use the **NVIDIA Nemotron-4-340B-Reward** model, which evaluates the quality of each response based on several criteria. This model provides scores that assess different aspects of the generated SQL commands. To use it we need to setup up the connection to the NVIDIA model using the OpenAI Python client. The base_url specifies the endpoint for the API, and the api_key is used for authentication. You can obtain your own API key by visiting this page: https://build.nvidia.com/nvidia/nemotron-4-340b-reward?snippet_tab=Python

# %%
from openai import OpenAI

client = OpenAI(
  base_url = "https://integrate.api.nvidia.com/v1",
  api_key = ""
)

# %% [markdown]
# We start by defining functions to evaluate the quality of responses using the NVIDIA Nemotron-4-340B-Reward API. The get_scores_from_response function extracts scores from the response. The get_response_and_scores function sends a pair of user instructions and model-generated responses to the model for evaluation, returning the score for each response.

# %%
def get_scores_from_response(score_response_template):
    logprobs = score_response_template.choices[0].logprobs.content
    score_dict = {}
    for score in logprobs:
        score_dict[score.token] = score.logprob
    return score_dict

# %%
def get_response_and_scores(client, model, question, response_content):
    messages = [
        {
            "role": "user",
            "content": question
        },
        {
            "role": "assistant",
            "content": response_content
        },
    ]

    response = client.chat.completions.create(
        model=model,
        messages=messages,
    )

    scores = get_scores_from_response(response)
    return scores

# %%
print(len(instruction_response_pair_list))
# Out:
# 201

# %% [markdown]
# We then define the process_instruction_response_score function, which iterates through each instruction-response pair in instruction_response_pair_list. For each pair, it retrieves the instruction and response, checks if they are valid, and then gets the evaluation scores. The scores are collected in a list.

# %%
def process_instruction_response_score(client, model, instruction_response_pair_list):
    score_list = []
    for instruction_response_pair in instruction_response_pair_list:
        instruction = instruction_response_pair.get("instruction")
        response = instruction_response_pair.get("responses")


        if instruction is not None and response is not None:
            score = get_response_and_scores(client, model, instruction, response)
            score_list.append(score)
        else:
            print(f"Skipping entry due to missing instruction or response: {instruction_response_pair}")

    return score_list

# %%
score_list = process_instruction_response_score(client, "nvidia/nemotron-4-340b-reward", instruction_response_pair_list)

# %%
score_list[:8]
# Out:
# [{'helpfulness': 3.703125,
#   'correctness': 3.59375,
#   'coherence': 3.875,
#   'complexity': 1.03125,
#   'verbosity': 0.291015625},
#  {'helpfulness': 2.96875,
#   'correctness': 2.984375,
#   'coherence': 3.6875,
#   'complexity': 0.8984375,
#   'verbosity': 0.345703125},
#  {'helpfulness': 3.34375,
#   'correctness': 3.46875,
#   'coherence': 3.96875,
#   'complexity': 1.09375,
#   'verbosity': 0.5546875},
#  {'helpfulness': 2.96875,
#   'correctness': 3.0625,
#   'coherence': 3.828125,
#   'complexity': 0.86328125,
#   'verbosity': 0.3671875},
#  {'helpfulness': 3.515625,
#   'correctness': 3.390625,
#   'coherence': 3.796875,
#   'complexity': 1.09375,
#   'verbosity': 0.52734375},
#  {'helpfulness': 3.171875,
#   'correctness': 3.03125,
#   'coherence': 3.4375,
#   'complexity': 1.375,
#   'verbosity': 0.90234375},
#  {'helpfulness': 3.0,
#   'correctness': 3.03125,
#   'coherence': 3.734375,
#   'complexity': 1.1015625,
#   'verbosity': 0.490234375},
#  {'helpfulness': 3.578125,
#   'correctness': 3.46875,
#   'coherence': 3.78125,
#   'complexity': 1.1796875,
#   'verbosity': 0.427734375}]

# %% [markdown]
# We finally filter the instruction_response_pair_list using two predefined thresholds:
#
# - The **helpfulness_THRESHOLD** is set to 3, meaning any response with a helpfulness score below 3 will be excluded.
# - The **verbosity_THRESHOLD** is set to 2.5, meaning any response with a verbosity score above 2.5 will be excluded.
#
# The synthetic_data list is created by iterating through the instruction_response_pair_list. This process ensures that only the most relevant and concise responses remain for further use.

# %%
helpfulness_THRESHOLD = 3
verbosity_THRESHOLD = 2.5
synthetic_data = [data for i, data in enumerate(instruction_response_pair_list)
                  if not (score_list[i]["helpfulness"] < helpfulness_THRESHOLD or
                          score_list[i]["verbosity"] > verbosity_THRESHOLD)]

# %%
synthetic_data
# Out:
# [{'instruction': 'Show me all the records from the customers table',
#   'responses': 'SELECT * FROM customers;'},
#  {'instruction': 'I need to see the total number of orders placed',
#   'responses': 'SELECT COUNT(*) AS total_orders FROM orders;'},
#  {'instruction': 'How do I find the highest price in the products table',
#   'responses': 'SELECT MAX(price) FROM products;'},
#  {'instruction': 'Can you pull the data for customers who made more than one purchase',
#   'responses': '```sql\nSELECT customer_id, COUNT(*) AS purchase_count\nFROM purchases\nGROUP BY customer_id\nHAVING COUNT(*) > 1;\n```'},
#  {'instruction': 'I want to see the average order amount',
#   'responses': 'SELECT AVG(order_amount) FROM orders;'},
#  {'instruction': 'How can I get a list of all unique cities from the addresses table',
#   'responses': 'SELECT DISTINCT city FROM addresses'},
#  {'instruction': 'I need the names of customers who have not placed any orders',
#   'responses': 'SELECT name FROM customers WHERE customer_id NOT IN (SELECT customer_id FROM orders)'},
#  {'instruction': 'How do I retrieve the first 5 rows from the users table',
#   'responses': 'SELECT * FROM users LIMIT 5;'},
#  {'instruction': 'I want to see the number of orders per month',
#   'responses': "SELECT DATE_TRUNC('month', order_date) AS month, COUNT(*) AS order_count FROM orders GROUP BY DATE_TRUNC('month', order_date) ORDER BY month;"},
#  {'instruction': 'Could you find the lowest price in the products table',
#   'responses': 'SELECT MIN(price) FROM products;'},
#  {'instruction': 'How can I get the count of customers in each city',
#   'responses': '```sql\nSELECT city, COUNT(*) AS customer_count\nFROM customers\nGROUP BY city;\n```'},
#  {'instruction': 'I need the names of customers who live in New York',
#   'responses': "SELECT name FROM customers WHERE city = 'New York'"},
#  {'instruction': 'I want to know the number of unique products in the inventory',
#   'responses': 'SELECT COUNT(DISTINCT product_id) FROM inventory;'},
#  {'instruction': 'Show me how to add a new column to an existing table',
#   'responses': 'ALTER TABLE table_name ADD column_name data_type;'},
#  {'instruction': 'I need to copy data from one table to another what SQL command should I use',
#   'responses': 'INSERT INTO target_table SELECT * FROM source_table;'},
#  {'instruction': 'Can you give me an example of how to insert data into a table',
#   'responses': 'INSERT INTO table_name (column1, column2, column3) VALUES (value1, value2, value3);'},
#  {'instruction': 'How can I change the data type of a column in a table',
#   'responses': 'ALTER TABLE table_name MODIFY column_name new_data_type;'},
#  {'instruction': 'What is the command to rename a table',
#   'responses': 'ALTER TABLE old_table_name RENAME TO new_table_name;'},
#  {'instruction': 'How can I select only certain columns from a table',
#   'responses': 'SELECT column1, column2, column3 FROM table_name;'},
#  {'instruction': 'What is the command to remove a column from a table',
#   'responses': 'ALTER TABLE table_name DROP COLUMN column_name;'},
#  {'instruction': 'Can you help me with a query to find the maximum value in a column',
#   'responses': 'SELECT MAX(column_name) FROM table_name;'},
#  {'instruction': 'How do I count the number of rows in a table',
#   'responses': 'SELECT COUNT(*) FROM table_name;'},
#  {'instruction': 'I need to calculate the average of a column how do I write the SQL command',
#   'responses': 'SELECT AVG(column_name) FROM table_name;'},
#  {'instruction': 'Can you show me how to group data by a column and get the sum of another column',
#   'responses': 'SELECT column1, SUM(column2) FROM table_name GROUP BY column1;'},
#  {'instruction': 'How do I join two tables based on a common column',
#   'responses': 'SELECT * FROM table1 JOIN table2 ON table1.common_column = table2.common_column;'},
#  {'instruction': 'I want to update multiple columns in a single row how do I do that',
#   'responses': 'UPDATE table_name SET column1 = value1, column2 = value2 WHERE condition;'},
#  {'instruction': 'Can you give me an example of how to use the WHERE clause to filter data',
#   'responses': "SELECT * FROM table_name WHERE column_name = 'value';"},
#  {'instruction': 'Create a table for storing customer information',
#   'responses': 'CREATE TABLE customers (\n    customer_id INT PRIMARY KEY,\n    first_name VARCHAR(50),\n    last_name VARCHAR(50),\n    email VARCHAR(100),\n    phone_number VARCHAR(15),\n    address VARCHAR(255)\n);'},
#  {'instruction': 'Add a column to an existing table for product prices',
#   'responses': 'ALTER TABLE products ADD COLUMN price DECIMAL(10, 2);'},
#  {'instruction': 'Remove a column from a table that is no longer needed',
#   'responses': 'ALTER TABLE table_name DROP COLUMN column_name;'},
#  {'instruction': 'Change the data type of a column in a table',
#   'responses': 'ALTER TABLE table_name MODIFY column_name new_data_type;'},
#  {'instruction': 'Rename a table to a more descriptive name',
#   'responses': 'ALTER TABLE old_table_name RENAME TO new_table_name;'},
#  {'instruction': 'Delete a table that is no longer in use',
#   'responses': 'DROP TABLE table_name;'},
#  {'instruction': 'Set a column as the primary key for a table',
#   'responses': 'ALTER TABLE table_name ADD PRIMARY KEY (column_name);'},
#  {'instruction': 'Add a foreign key to link two tables together',
#   'responses': 'ALTER TABLE table_name1 ADD FOREIGN KEY (column_name) REFERENCES table_name2(column_name);'},
#  {'instruction': 'Create an index on a column to speed up queries',
#   'responses': 'CREATE INDEX idx_column_name ON table_name (column_name);'},
#  {'instruction': 'Drop an index from a column that is rarely used',
#   'responses': 'DROP INDEX index_name ON table_name;'},
#  {'instruction': 'Alter a table to add multiple columns at once',
#   'responses': 'ALTER TABLE table_name ADD (column1 datatype, column2 datatype, column3 datatype);'},
#  {'instruction': 'Change the name of a column to be more clear',
#   'responses': 'ALTER TABLE table_name RENAME COLUMN old_column_name TO new_column_name;'},
#  {'instruction': 'Add a unique constraint to a column to avoid duplicates',
#   'responses': 'ALTER TABLE table_name ADD CONSTRAINT constraint_name UNIQUE (column_name);'},
#  {'instruction': 'Drop a view that is no longer needed',
#   'responses': 'DROP VIEW view_name;'},
#  {'instruction': 'Remove a check constraint that is no longer necessary',
#   'responses': 'ALTER TABLE table_name DROP CONSTRAINT constraint_name;'},
#  {'instruction': 'Delete a database that is no longer required',
#   'responses': 'DROP DATABASE database_name;'},
#  {'instruction': 'Can you show me how to grant all privileges to a user',
#   'responses': "GRANT ALL PRIVILEGES ON *.* TO 'username'@'localhost';"},
#  {'instruction': 'What is the syntax to revoke a specific privilege from a user',
#   'responses': 'REVOKE privilege_name ON object_name FROM user_name;'},
#  {'instruction': 'What is the syntax for beginning a transaction',
#   'responses': 'BEGIN TRANSACTION;'},
#  {'instruction': 'What is the command to end a transaction successfully',
#   'responses': 'COMMIT;'},
#  {'instruction': 'Can you give an example of a transaction with a rollback',
#   'responses': 'BEGIN TRANSACTION;\n\nUPDATE accounts SET balance = balance - 100 WHERE account_id = 1;\nUPDATE accounts SET balance = balance + 100 WHERE account_id = 2;\n\nROLLBACK;'},
#  {'instruction': 'How to handle errors during a transaction',
#   'responses': 'BEGIN TRY\n    BEGIN TRANSACTION;\n    -- SQL statements go here\n    COMMIT TRANSACTION;\nEND TRY\nBEGIN CATCH\n    ROLLBACK TRANSACTION;\n    -- Optionally, log the error or handle it as needed\nEND CATCH;'},
#  {'instruction': 'I want to see all the users in the database',
#   'responses': 'SELECT * FROM users;'},
#  {'instruction': 'How can I check the current users privileges',
#   'responses': 'SHOW GRANTS FOR CURRENT_USER();'},
#  {'instruction': 'I need to create a read only user for reporting',
#   'responses': "CREATE USER 'report_user'@'localhost' IDENTIFIED BY 'password';\nGRANT SELECT ON *.* TO 'report_user'@'localhost';"},
#  {'instruction': 'Create an index for the users table on the email column',
#   'responses': 'CREATE INDEX idx_users_email ON users (email);'},
#  {'instruction': 'Add an index to speed up searches on the product name',
#   'responses': 'CREATE INDEX idx_product_name ON products (product_name);'},
#  {'instruction': 'I want to create a unique index on the username field',
#   'responses': 'CREATE UNIQUE INDEX idx_username ON users (username);'},
#  {'instruction': 'How do I drop an index that is causing issues',
#   'responses': 'DROP INDEX index_name ON table_name;'},
#  {'instruction': 'Add a composite index on the first name and last name columns',
#   'responses': 'CREATE INDEX idx_first_last_name ON users (first_name, last_name);'},
#  {'instruction': 'Improve query performance by adding an index to the most searched column',
#   'responses': 'CREATE INDEX idx_most_searched_column ON table_name (most_searched_column);'},
#  {'instruction': 'Create a view that shows only the active users',
#   'responses': "SELECT * FROM users WHERE status = 'active';"},
#  {'instruction': 'I need a view that combines data from users and their orders',
#   'responses': 'CREATE VIEW user_orders AS SELECT users.user_id, users.name, orders.order_id, orders.order_date, orders.total_amount FROM users JOIN orders ON users.user_id = orders.user_id;'},
#  {'instruction': 'Can you make a view that filters out inactive accounts',
#   'responses': "CREATE VIEW ActiveAccounts AS SELECT * FROM Accounts WHERE status = 'active';"},
#  {'instruction': 'Show me how to delete a view I no longer need',
#   'responses': 'DROP VIEW view_name;'},
#  {'instruction': 'I want to create a view that summarizes sales by month',
#   'responses': "CREATE VIEW SalesByMonth AS SELECT DATE_TRUNC('month', sale_date) AS Month, SUM(sale_amount) AS TotalSales FROM sales GROUP BY DATE_TRUNC('month', sale_date);"},
#  {'instruction': 'I need a view that only shows the top 10 customers by purchase amount',
#   'responses': 'CREATE VIEW Top10CustomersByPurchase AS SELECT customer_id, SUM(purchase_amount) AS total_spent FROM purchases GROUP BY customer_id ORDER BY total_spent DESC LIMIT 10;'},
#  {'instruction': 'How can I rename a view I created earlier',
#   'responses': 'ALTER VIEW old_view_name RENAME TO new_view_name;'}]

# %% [markdown]
# ### **Step 6: Saving and Deploying the Dataset**
#
# Now we can save the filtered synthetic data to a file and then deploy it as a dataset on Hugging Face. Here’s how the process works:
#
# We save the filtered data to a file called synthetic_data_filtered.jsonl, where each item is stored as a separate JSON object for easy handling. After that, we log into our Hugging Face account using the huggingface_hub.login() function to upload the dataset to the platform. The dataset is then organized into a DatasetDict with a key called train, preparing it for use in machine learning tasks. Finally, we upload the dataset to Hugging Face using dataset_dict.push_to_hub(), making it publicly available for others to access and use.

# %%
import json

# %%
with open('synthetic_data_filtered.jsonl', 'w') as f:
    for item in synthetic_data:
        f.write(json.dumps(item))
        f.write('\n')

# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.27.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 29.8 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.0 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 16.0 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.8 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.0 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.2.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
from datasets import Dataset, DatasetDict, load_dataset

# %%
with open(f'synthetic_data_filtered.jsonl', 'r') as f:
    data = [json.loads(line) for line in f]
dataset = Dataset.from_list(data)
dataset_dict = DatasetDict({"train": dataset})
dataset_dict.push_to_hub("melekmessoussi/SQL-prompt-dataset3")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/melekmessoussi/SQL-prompt-dataset3/commit/4a590c3a0ed1f96a5bb40f1266d7ea7f57abe65f', commit_message='Upload dataset', commit_description='', oid='4a590c3a0ed1f96a5bb40f1266d7ea7f57abe65f', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/melekmessoussi/SQL-prompt-dataset3', endpoint='https://huggingface.co', repo_type='dataset', repo_id='melekmessoussi/SQL-prompt-dataset3'), pr_revision=None, pr_num=None)

# %% [markdown]
# Voilà! Now you have a dataset ready to fine-tune any model.
